# %% [markdown]
# # Police Dataset

# %% [markdown]
# Here,
# The data from a Police Check Post is given.
#
# This data is available as a CSV file. We are going to analyze this data set using the Pandas DataFrame.

# %%
import pandas as pd

# %%
df =pd. read_csv("3. Police Data.csv")

# %%
df
# Out:
#        stop_date stop_time  country_name driver_gender  driver_age_raw  \
# 0       1/2/2005      1:55           NaN             M          1985.0
# 1      1/18/2005      8:15           NaN             M          1965.0
# 2      1/23/2005     23:15           NaN             M          1972.0
# 3      2/20/2005     17:15           NaN             M          1986.0
# 4      3/14/2005     10:00           NaN             F          1984.0
# ...          ...       ...           ...           ...             ...
# 65530  12/6/2012     17:54           NaN             F          1987.0
# 65531  12/6/2012     22:22           NaN             M          1954.0
# 65532  12/6/2012     23:20           NaN             M          1985.0
# 65533  12/7/2012      0:23           NaN           NaN             NaN
# 65534  12/7/2012      0:30           NaN             F          1985.0
#
#        driver_age driver_race                   violation_raw  violation  \
# 0            20.0       White                        Speeding   Speeding
# 1            40.0       White                        Speeding   Speeding
# 2            33.0       White                        Speeding   Speeding
# 3            19.0       White                Call for Service      Other
# 4            21.0       White                        Speeding   Speeding
# ...           ...         ...                             ...        ...
# 65530        25.0       White                        Speeding   Speeding
# 65531        58.0       White                        Speeding   Speeding
# 65532        27.0       Black  Equipment/Inspection Violation  Equipment
# 65533         NaN         NaN                             NaN        NaN
# 65534        27.0       White                        Speeding   Speeding
#
#        search_conducted search_type   stop_outcome is_arrested stop_duration  \
# 0                 False         NaN       Citation       False      0-15 Min
# 1                 False         NaN       Citation       False      0-15 Min
# 2                 False         NaN       Citation       False      0-15 Min
# 3                 False         NaN  Arrest Driver        True     16-30 Min
# 4                 False         NaN       Citation       False      0-15 Min
# ...                 ...         ...            ...         ...           ...
# 65530             False         NaN       Citation       False      0-15 Min
# 65531             False         NaN        Warning       False      0-15 Min
# 65532             False         NaN       Citation       False      0-15 Min
# 65533             False         NaN            NaN         NaN           NaN
# 65534             False         NaN       Citation       False      0-15 Min
#
#        drugs_related_stop
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False
# ...                   ...
# 65530               False
# 65531               False
# 65532               False
# 65533               False
# 65534               False
#
# [65535 rows x 15 columns]

# %% [markdown]
# # Instruction ( For Data Cleaning )
#
# 1. Remove the column that only contains missing values

# %%
df.isnull().sum()
# Out:
# stop_date                 0
# stop_time                 0
# country_name          65535
# driver_gender          4061
# driver_age_raw         4054
# driver_age             4307
# driver_race            4060
# violation_raw          4060
# violation              4060
# search_conducted          0
# search_type           63056
# stop_outcome           4060
# is_arrested            4060
# stop_duration          4060
# drugs_related_stop        0
# dtype: int64

# %%
df.drop(columns = "country_name", inplace = True)

# %%
df
# Out:
#        stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0       1/2/2005      1:55             M          1985.0        20.0
# 1      1/18/2005      8:15             M          1965.0        40.0
# 2      1/23/2005     23:15             M          1972.0        33.0
# 3      2/20/2005     17:15             M          1986.0        19.0
# 4      3/14/2005     10:00             F          1984.0        21.0
# ...          ...       ...           ...             ...         ...
# 65530  12/6/2012     17:54             F          1987.0        25.0
# 65531  12/6/2012     22:22             M          1954.0        58.0
# 65532  12/6/2012     23:20             M          1985.0        27.0
# 65533  12/7/2012      0:23           NaN             NaN         NaN
# 65534  12/7/2012      0:30             F          1985.0        27.0
#
#       driver_race                   violation_raw  violation  \
# 0           White                        Speeding   Speeding
# 1           White                        Speeding   Speeding
# 2           White                        Speeding   Speeding
# 3           White                Call for Service      Other
# 4           White                        Speeding   Speeding
# ...           ...                             ...        ...
# 65530       White                        Speeding   Speeding
# 65531       White                        Speeding   Speeding
# 65532       Black  Equipment/Inspection Violation  Equipment
# 65533         NaN                             NaN        NaN
# 65534       White                        Speeding   Speeding
#
#        search_conducted search_type   stop_outcome is_arrested stop_duration  \
# 0                 False         NaN       Citation       False      0-15 Min
# 1                 False         NaN       Citation       False      0-15 Min
# 2                 False         NaN       Citation       False      0-15 Min
# 3                 False         NaN  Arrest Driver        True     16-30 Min
# 4                 False         NaN       Citation       False      0-15 Min
# ...                 ...         ...            ...         ...           ...
# 65530             False         NaN       Citation       False      0-15 Min
# 65531             False         NaN        Warning       False      0-15 Min
# 65532             False         NaN       Citation       False      0-15 Min
# 65533             False         NaN            NaN         NaN           NaN
# 65534             False         NaN       Citation       False      0-15 Min
#
#        drugs_related_stop
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False
# ...                   ...
# 65530               False
# 65531               False
# 65532               False
# 65533               False
# 65534               False
#
# [65535 rows x 14 columns]

# %% [markdown]
# # Question ( Based on Filtering + Value Counts )
#
# 2. For Speeding , were Men or Women stopped more often ?

# %%
df[df.violation == "Speeding"].driver_gender.value_counts()
# Out:
# M    45164
# F    16310
# Name: driver_gender, dtype: int64

# %% [markdown]
# # Question ( Groupby )
#
# 3. Does gender affect who gets searched during a stop ?

# %%
df.search_conducted.value_counts()
# Out:
# False    63056
# True      2479
# Name: search_conducted, dtype: int64

# %%
df.groupby(df[df.search_conducted == True].driver_gender).search_conducted.sum()
# Out:
# driver_gender
# F     366
# M    2113
# Name: search_conducted, dtype: int64

# %% [markdown]
# # Question ( mapping + data-type casting )
#
# 4. What is the mean stop_duration ?

# %%
df.stop_duration.value_counts()
# Out:
# 0-15 Min     47379
# 16-30 Min    11448
# 30+ Min       2647
# 2                1
# Name: stop_duration, dtype: int64

# %%
df["stop_duration"] = df["stop_duration"].map({"0-15 Min" :7,"16-30 Min" :24,"30+ Min":45})

# %%
df
# Out:
#        stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0       1/2/2005      1:55             M          1985.0        20.0
# 1      1/18/2005      8:15             M          1965.0        40.0
# 2      1/23/2005     23:15             M          1972.0        33.0
# 3      2/20/2005     17:15             M          1986.0        19.0
# 4      3/14/2005     10:00             F          1984.0        21.0
# ...          ...       ...           ...             ...         ...
# 65530  12/6/2012     17:54             F          1987.0        25.0
# 65531  12/6/2012     22:22             M          1954.0        58.0
# 65532  12/6/2012     23:20             M          1985.0        27.0
# 65533  12/7/2012      0:23           NaN             NaN         NaN
# 65534  12/7/2012      0:30             F          1985.0        27.0
#
#       driver_race                   violation_raw violation  search_conducted  \
# 0           White                        Speeding  Speeding             False
# 1           White                        Speeding  Speeding             False
# 2           White                        Speeding  Speeding             False
# 3           White                Call for Service  Speeding             False
# 4           White                        Speeding  Speeding             False
# ...           ...                             ...       ...               ...
# 65530       White                        Speeding  Speeding             False
# 65531       White                        Speeding  Speeding             False
# 65532       Black  Equipment/Inspection Violation  Speeding             False
# 65533         NaN                             NaN  Speeding             False
# 65534       White                        Speeding  Speeding             False
#
#       search_type   stop_outcome is_arrested  stop_duration  \
# 0             NaN       Citation       False            7.0
# 1             NaN       Citation       False            7.0
# 2             NaN       Citation       False            7.0
# 3             NaN  Arrest Driver        True           24.0
# 4             NaN       Citation       False            7.0
# ...           ...            ...         ...            ...
# 65530         NaN       Citation       False            7.0
# 65531         NaN        Warning       False            7.0
# 65532         NaN       Citation       False            7.0
# 65533         NaN            NaN         NaN            NaN
# 65534         NaN       Citation       False            7.0
#
#        drugs_related_stop  Speeding
# 0                   False  Speeding
# 1                   False  Speeding
# 2                   False  Speeding
# 3                   False  Speeding
# 4                   False  Speeding
# ...                   ...       ...
# 65530               False  Speeding
# 65531               False  Speeding
# 65532               False  Speeding
# 65533               False  Speeding
# 65534               False  Speeding
#
# [65535 rows x 15 columns]

# %%
df["stop_duration"].mean()
# Out:
# 11.802062660637016

# %% [markdown]
# # Question ( Groupby , Describe )
#
# 5. Compare the age distributions for each violation

# %%
df.groupby("violation_raw").driver_age.describe()
# Out:
#                                     count       mean        std   min    25%  \
# violation_raw
# APB                                  50.0  35.360000  11.547170  18.0  26.00
# Call for Service                    786.0  33.717557  13.153832  16.0  23.00
# Equipment/Inspection Violation     6507.0  31.682957  11.380671  16.0  23.00
# Motorist Assist/Courtesy            127.0  35.464567  12.424244  17.0  25.00
# Other Traffic Violation           11876.0  36.736443  13.258350  15.0  25.00
# Registration Violation             2240.0  32.656696  11.150780  16.0  24.00
# Seatbelt Violation                    3.0  30.333333  10.214369  23.0  24.50
# Special Detail/Directed Patrol     2298.0  43.549608  11.430333  17.0  35.00
# Speeding                          37120.0  33.262581  12.615781  15.0  23.00
# Suspicious Person                    36.0  32.055556  12.741259  18.0  22.75
# Violation of City/Town Ordinance    170.0  35.311765  12.532674  18.0  24.00
# Warrant                              10.0  33.200000  13.489090  20.0  24.25
#
#                                    50%    75%   max
# violation_raw
# APB                               34.0  42.75  72.0
# Call for Service                  30.0  42.00  86.0
# Equipment/Inspection Violation    28.0  39.00  81.0
# Motorist Assist/Courtesy          32.0  46.00  63.0
# Other Traffic Violation           35.0  47.00  86.0
# Registration Violation            30.0  40.00  74.0
# Seatbelt Violation                26.0  34.00  42.0
# Special Detail/Directed Patrol    44.0  52.00  78.0
# Speeding                          30.0  42.00  88.0
# Suspicious Person                 28.0  41.00  69.0
# Violation of City/Town Ordinance  33.0  46.00  66.0
# Warrant                           29.0  38.50  63.0
